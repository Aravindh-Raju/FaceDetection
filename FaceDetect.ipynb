# %% [markdown]
# Example 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("/content/group_photo.jpg")

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
plt.imshow(img)

# %%
import cv2

# %%
model = cv2.CascadeClassifier("/content/haarcascade_frontalface_alt.xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces
# Out:
# array([[374,  34,  55,  55],
#        [ 63,  38,  59,  59],
#        [296,  24,  56,  56],
#        [207,  72,  53,  53],
#        [439,  92,  49,  49],
#        [108,  86,  48,  48],
#        [168, 118,  46,  46]], dtype=int32)

# %%
faces.shape
# Out:
# (7, 4)

# %%
for face in faces:
  x,y,w,h = face

  img = cv2.rectangle(img, (x,y), (x+w, y+h), (200,0,0), 2 )

# %%
plt.imshow(img)

# %% [markdown]
# Example 2

# %%
img = plt.imread("/content/THE+REAL+GROUP+2020+-+3.jpg")

# %%
img.shape
# Out:
# (1406, 2500, 3)

# %%
plt.imshow(img)

# %%
model = cv2.CascadeClassifier("/content/haarcascade_frontalface_alt.xml")

# %%
faces = model.detectMultiScale(img)

# %%
faces
# Out:
# array([[ 818,  192,  260,  260],
#        [1438,  365,  293,  293],
#        [ 357,  548,  300,  300],
#        [ 953,  762,  325,  325],
#        [1826,  790,  328,  328]], dtype=int32)

# %%
faces.shape
# Out:
# (5, 4)

# %%
for face in faces:
  x,y,w,h = face

  img = cv2.rectangle(img, (x,y), (x+w, y+h), (200,0,0), 10 )

# %%
plt.imshow(img)
